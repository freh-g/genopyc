# %%
import genopyc as gp
import requests

# %%
def get_ov_region(chromosome,start,stop,features=list):
    str_features=';'.join(['feature='+x for x in features])
    http="https://rest.ensembl.org/overlap/region/human/%s:%s-%s?%s"%(chromosome,start,stop,str_features)
    risposta=requests.get(http,headers={ "Content-Type" : "application/json"}).json()
    return risposta

# %% [markdown]
# Enum(band, gene, transcript, cds, exon, repeat, simple, misc, variation, somatic_variation, structural_variation, somatic_structural_variation, constrained, regulatory, motif, other_regulatory, array_probe, mane)

# %%
r=get_ov_region(10,117502854-500,117502854+500,features=['motif','gene'])

# %%
r
# Out:
# [{'score': 5.22184845355,
#   'end': 117502931,
#   'strand': 1,
#   'start': 117502910,
#   'seq_region_name': '10',
#   'feature_type': 'motif',
#   'binding_matrix_stable_id': 'ENSPFM0067',
#   'stable_id': 'ENSM00238577010',
#   'transcription_factor_complex': 'E2F1::ELK1'},
#  {'end': 117502927,
#   'score': 4.93272914565,
#   'strand': -1,
#   'start': 117502914,
#   'seq_region_name': '10',
#   'feature_type': 'motif',
#   'binding_matrix_stable_id': 'ENSPFM0506',
#   'transcription_factor_complex': 'TEAD4::SPIB,TEAD4::ELF1,TEAD4::ELK1',
#   'stable_id': 'ENSM00461319468'},
#  {'binding_matrix_stable_id': 'ENSPFM0217',
#   'seq_region_name': '10',
#   'feature_type': 'motif',
#   'stable_id': 'ENSM00310950022',
#   'transcription_factor_complex': 'GCM1::ELF1',
#   'score': 3.82251312335,
#   'end': 117502929,
#   'start': 117502914,
#   'strand': -1},
#  {'strand': -1,
#   'start': 117502914,
#   'score': 5.69283782023,
#   'end': 117502935,
# ...
